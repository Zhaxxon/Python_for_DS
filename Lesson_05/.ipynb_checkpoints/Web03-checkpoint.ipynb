# %% [markdown]
# # Вебинар 3. Визуализация и анализ данных.

# %% [markdown]
# ![houses.gif](houses.gif)

# %% [markdown]
# **Подключение библиотек и скриптов**

# %%
import numpy as np
import pandas as pd

import warnings
warnings.simplefilter('ignore')

# %matplotlib inline
import matplotlib.image as img
import matplotlib.pyplot as plt

import seaborn as sns
# %config InlineBackend.figure_format = 'svg' 
from pylab import rcParams
rcParams['figure.figsize'] = 12, 6  # меняем размер графиков по умолчанию

# %% [markdown]
# **Пути к директориям и файлам**

# %%
PREPARED_DATASET_PATH = 'data/housing_prepared.csv'
CALIFORNIA_MAP_PATH = 'California_Map.png'

# %% [markdown]
# ### Загрузка данных

# %% [markdown]
# **Описание датасета**
#
# Статистические данные о ряде домов в Калифорнии, основанные на переписи 1990 года.
#
# * **longitude** - долгота
# * **latitude** - широта
# * **housing_median_age** - средний возраст дома
# * **total_rooms** - общее количество комнат
# * **total_bedrooms** - общее количество спален
# * **population** - количество проживающих
# * **households** - число бывших владельцев
# * **ocean_proximity** - близость океана
# * **median_income** - средний доход
# * **median_house_value** - средняя стоимость дома

# %%
df = pd.read_csv(PREPARED_DATASET_PATH)
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# ...

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# <1H OCEAN               int64
# INLAND                  int64
# ISLAND                  int64
# NEAR BAY                int64
# NEAR OCEAN              int64
# dtype: object

# %% [markdown]
# Прежде чем мы перейдем к рассмотрению методов библиотек matplotlib и seaborn, обсудим самый простой и зачастую удобный способ визуализировать данные из pandas DataFrame — это воспользоваться функцией plot.
# Для примера построим график зависомости средней цены за дом относительно признака ocean_proximity.
# Для сгруппируем наши данные по этому признаку, посчитаем средние значение median_house_value и у получившегося DataFrame вызовем функцию plot без параметров.

# %%
# df.groupby('ocean_proximity')['median_house_value'].mean().plot();
# df.groupby('ocean_proximity')['median_house_value'].mean().plot(kind='bar', rot=45);

# %% [markdown]
# ### Анализ целевой переменной

# %% [markdown]
# Matplotlib - это базавая библиотека python для визуализации
# Seaborn — это по сути более высокоуровневое API на базе библиотеки matplotlib. Seaborn содержит более адекватные дефолтные настройки оформления графиков. Также в библиотеке есть достаточно сложные типы визуализации, которые в matplotlib потребовали бы большого количество кода.

# %%
# plt.figure(figsize = (12, 6))

# plt.subplot(121)
# df['median_house_value'].hist()
# plt.ylabel('count')
# plt.xlabel('median_house_value')

# plt.subplot(122)
# sns.kdeplot(df['median_house_value'], shade=True, legend=False)
# plt.xlabel('median_house_value')

# plt.suptitle('Distribution of median_house_value')
# plt.show();

# %%
# target_mean = round(df['median_house_value'].mean(), 2)
# target_median = df['median_house_value'].median()
# target_mode = df['median_house_value'].mode()[0]

# print('Среднее:', target_mean) 
# print('Медиана:', target_median) 
# print('Мода:', target_mode)

# %%
# # plt.figure(figsize = (12, 6))
# sns.distplot(df['median_house_value'])

# y = np.linspace(0, 0.000005, 100)
# plt.plot([target_mean] * 100, y, label='mean', linestyle='-', linewidth=4)
# plt.plot([target_median] * 100, y, label='median', linestyle='-', linewidth=4)
# plt.plot([target_mode] * 100, y, label='mode', linestyle='-', linewidth=4)
# plt.title('Distribution of median_house_value')
# plt.legend(loc = 'upper left')
# plt.show()

# %% [markdown]
# ## Оценка распредения целевой переменной в разрезе других признаков

# %%
df_num_features = df.select_dtypes(include='float64')  # отбираем количественные признаки

# %%
sns.pairplot(df_num_features);

# %%
# plt.savefig('df_pairplot.svg')

# %% [markdown]
# ## Анализ категориальных переменных

# %% [markdown]
# ### Box plot

# %% [markdown]
# - Средняя линия - медина (2-ой квартиль)
# - Границы "ящика" - 1-й и 3-й квартили (межквартильный размах)
# - Границы "усов" - +/- 1.5 межквартильного размаха от границ "ящика"
# - Значения вне границы "усов" - выборосы

# %% [markdown]
# <img src="boxplot.png" alt="Drawing" style="width: 600px;">

# %%
# # plt.figure(figsize=(16, 8))
# sns.boxplot(df['ocean_proximity'],df['median_house_value'])
# plt.xlabel('ocean_proximity')
# plt.ylabel('median_house_value')
# plt.title('Distribution of median_house_value by ocean_proximity')
# plt.show();

# %% [markdown]
# ### Violin plot

# %%
# # plt.figure(figsize=(16, 8))
# sns.violinplot(df['ocean_proximity'], df['median_house_value'])
# plt.ylabel('median_house_value')
# plt.xlabel('ocean_proximity')
# plt.title('Distribution of median_house_value by ocean_proximity')
# plt.show();

# %% [markdown]
# ---

# %% [markdown]
# ## Анализ количественных признаков

# %%
# df_num_features.hist(figsize=(12, 8), bins=20, grid=False);

# %% [markdown]
# Функция jointplot() показывает совместное распределение по двум переменным.
# Она имеет параметр kind который может принимать следующие значения:
# - “scatter”
# - “reg”
# - “resid”
# - “kde”
# - “hex”

# %%
# grid = sns.jointplot(df['total_rooms'], df['total_bedrooms'], kind='reg');
# grid.fig.set_figwidth(6)
# grid.fig.set_figheight(6)

# %% [markdown]
# ### Корреляция признаков

# %%
# corr = df_num_features.corr()
# plt.figure(figsize = (8, 8))
# mask = np.zeros_like(corr, dtype=np.bool)  # отрезаем лишнюю половину матрицы
# mask[np.triu_indices_from(mask)] = True
# sns.set(font_scale=1.4)
# sns.heatmap(df_num_features.corr(), mask=mask, annot=True, fmt='.1f', linewidths=.5, cmap='GnBu')
# plt.title('Correlation matrix')
# plt.show();

# %% [markdown]
# ### Анализ бинарных признаков

# %%
df_bin_features = df.select_dtypes(include='int64')

# %%
# for i, colname in enumerate(df_bin_features.columns):
#     counts = df_bin_features[colname].value_counts()
#     plt.subplot(3,2,i+1)    
#     plt.title(colname)
#     sns.barplot(counts.index, counts.values)
# plt.show();

# %% [markdown]
# ## Визуализация данных на карте

# %%
california_map = img.imread(CALIFORNIA_MAP_PATH)

# %%
df.plot(kind='scatter', x='longitude', y='latitude', alpha=0.5, 
        s=df['population'] / 50, label='population', c='median_house_value', 
        cmap=plt.get_cmap('jet'), figsize=(20,13))

plt.imshow(california_map, extent=[-124.55, -113.80, 32.45, 42.05], alpha=0.5)

plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Homes geography")
plt.legend() 
plt.show()
